# %%
import networkx as nx
import matplotlib.pyplot as plt
import src.data.synthetic.gengraph as gengraph

# %%
g_1 = gengraph.gen_syn1(5, 10)[0]
fig = plt.figure(figsize=(8, 6))
nx.draw(g_1, with_labels=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 g_1 = gengraph.gen_syn1(5, 10)[0]
#       2 fig = plt.figure(figsize=(8, 6))
#       3 nx.draw(g_1, with_labels=True)
#
# NameError: name 'gengraph' is not defined

# %%
g_3 = gengraph.gen_syn3(5, 10)[0]
fig = plt.figure(figsize=(8, 6))
nx.draw(g_3, with_labels=True)
# Out:
# feat_dict[0]["feat"]: float32
# G.nodes[0]["feat"]: float32
